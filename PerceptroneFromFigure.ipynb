# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjayBista1010/DeepLearning/blob/main/PerceptroneFromFigure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

x = [[1.5, 3, 3.5]]

N = len(x)
epochs = 1000

weights = [0.25, 0.11, 0.05]
bias = 0.25

for i in range(epochs):
    total_error = 0

    for j in range(N):
        z = sum([weights[k] * x[j][k] for k in range(len(weights))]) + bias

        y_pred = 1 if (1 / (1 + math.exp(-z))) >= 0.5 else 0
        '''error = y[j] - y_pred

        weights = [weights[k] + x[j][k] * error for k in range(len(weights))]
        bias += error

        total_error += error ** 2

    if i % 100 == 0:
        mse = total_error / N
        print(f"Epoch {i} MSE = {mse:.4f}, weights={weights}, bias={bias:.3f}")'''

print(f"Final Output: {y_pred}")
# Out:
# Final Output: 1
